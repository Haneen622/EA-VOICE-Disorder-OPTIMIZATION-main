# %%
# استيراد ملف التقسيم مثلاً
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # استيراد ملف التقسيم مثلاً
# ----> 2 from split_data import *
#       4 print("تم استيراد الكود بنجاح ✅")
#
# File ~\OneDrive\Desktop\Graduation_project\EA-VOICE-Disorder-OPTIMIZATION-main\EA-VOICE-Disorder-OPTIMIZATION-main\split_data.py:11
#       9 from sklearn.metrics import recall_score
#      10 from sklearn.metrics import precision_score
# ---> 11 from lightgbm import LGBMClassifier
#      14 from sklearn.svm import SVC
#      15 from sklearn.metrics import classification_report
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/72.0 MB 1.5 MB/s eta 0:00:47
#     --------------------------------------- 1.0/72.0 MB 1.6 MB/s eta 0:00:44
#     --------------------------------------- 1.3/72.0 MB 1.6 MB/s eta 0:00:45
#     --------------------------------------- 1.6/72.0 MB 1.5 MB/s eta 0:00:47
#    - -------------------------------------- 1.8/72.0 MB 1.5 MB/s eta 0:00:48
#    - -------------------------------------- 2.4/72.0 MB 1.5 MB/s eta 0:00:48
#    - -------------------------------------- 2.6/72.0 MB 1.5 MB/s eta 0:00:48
#    - -------------------------------------- 3.1/72.0 MB 1.5 MB/s eta 0:00:48
#    - -------------------------------------- 3.4/72.0 MB 1.5 MB/s eta 0:00:48
# ...

# %%
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from split_data import *
#       3 print("تم استيراد الكود بنجاح ✅")
#
# File ~\OneDrive\Desktop\Graduation_project\EA-VOICE-Disorder-OPTIMIZATION-main\EA-VOICE-Disorder-OPTIMIZATION-main\split_data.py:11
#       9 from sklearn.metrics import recall_score
#      10 from sklearn.metrics import precision_score
# ---> 11 from lightgbm import LGBMClassifier
#      14 from sklearn.svm import SVC
#      15 from sklearn.metrics import classification_report
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from split_data import *
#       3 print("تم استيراد الكود بنجاح ✅")
#
# File ~\OneDrive\Desktop\Graduation_project\EA-VOICE-Disorder-OPTIMIZATION-main\EA-VOICE-Disorder-OPTIMIZATION-main\split_data.py:11
#       9 from sklearn.metrics import recall_score
#      10 from sklearn.metrics import precision_score
# ---> 11 from lightgbm import LGBMClassifier
#      14 from sklearn.svm import SVC
#      15 from sklearn.metrics import classification_report
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
# !pip install numpy pandas scikit-learn xgboost lightgbm shap matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 838.7 kB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 838.7 kB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 838.7 kB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 838.7 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.5 MB 566.0 kB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 691.8 kB/s eta 0:00:00
# ...

# %%
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from split_data import *
#       3 print("تم استيراد الكود بنجاح ✅")
#
# File ~\OneDrive\Desktop\Graduation_project\EA-VOICE-Disorder-OPTIMIZATION-main\EA-VOICE-Disorder-OPTIMIZATION-main\split_data.py:17
#      14 from sklearn.svm import SVC
#      15 from sklearn.metrics import classification_report
# ---> 17 df = pd.read_csv('data/svd_handcrafted_data.tsv', sep='\t')
#      18 df = df.drop(columns=['path'])
#      19 print(df.head())
#
# ...

# %%
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from split_data import *
#       3 print("تم استيراد الكود بنجاح ✅")
#
# File ~\OneDrive\Desktop\Graduation_project\EA-VOICE-Disorder-OPTIMIZATION-main\EA-VOICE-Disorder-OPTIMIZATION-main\split_data.py:21
#      15 from sklearn.metrics import classification_report
#      17 #df = pd.read_csv('data/svd_handcrafted_data.tsv', sep='\t')
#      18 #df = df.drop(columns=['path'])
#      19 #print(df.head())
# ---> 21 train, test = train_test_split(df, test_size=0.2, stratify=df['label'].values.tolist(), shuffle=True)
#      22 print(train.shape)
#      23 print(test.shape)
#
# NameError: name 'df' is not defined

# %%
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 1
#     from split_data import *
#
#   File ~\OneDrive\Desktop\Graduation_project\EA-VOICE-Disorder-OPTIMIZATION-main\EA-VOICE-Disorder-OPTIMIZATION-main\split_data.py:24
#     df = pd.DataFrame({
#                       ^
# SyntaxError: '{' was never closed

# %%
from split_data import *

print("تم استيراد الكود بنجاح ✅")
# Out:
# ✅ تم إنشاء بيانات تجريبية:
#    feature1  feature2  feature3  feature4  label
# 0  0.449011  0.828890  0.660408  0.280937      0
# 1  0.596590  0.019758  0.464549  0.455946      1
# 2  0.722317  0.217748  0.675388  0.404582      0
# 3  0.754043  0.341067  0.422575  0.253102      0
# 4  0.343225  0.400619  0.707600  0.253966      0
# أشكال المجموعات:
# (80, 5)
# (20, 5)
#
# توزيع القيم في train:
# label
# 0    41
# 1    39
# Name: count, dtype: int64
#
# توزيع القيم في test:
# label
# 1    10
# 0    10
# Name: count, dtype: int64
#
# 📊 تقرير التصنيف:
#               precision    recall  f1-score   support
#
#            0      0.364     0.400     0.381        10
#            1      0.333     0.300     0.316        10
#
#     accuracy                          0.350        20
#    macro avg      0.348     0.350     0.348        20
# weighted avg      0.348     0.350     0.348        20
#
# Accuracy: 35.000%
# F1-score: 0.3483709273182957
# Recall: 0.35
# Precision: 0.3484848484848485
# ...
